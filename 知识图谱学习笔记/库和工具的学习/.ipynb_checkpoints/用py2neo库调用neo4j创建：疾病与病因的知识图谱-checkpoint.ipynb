# %% [markdown]
# 在本节，我们尝试调用Python库 `py2neo` 调用`neo4j`来创建疾病与病因的数据库。

# %% [markdown]
# # 安装py2neo库

# %% [markdown]
# `pip install py2neo`

# %% [markdown]
# # 数据初探

# %% [markdown]
# 我们的数据存储在`./data/disease_cause_entity_label.txt`中，数据格式为:
#
# |字段1|分隔符|字段2|分隔符|字段3|分隔符|字段4|分隔符|字段5|
# |--|--|--|--|--|--|--|--|--|
# |疾病|<->|病因|<->|具体病因|<->|实体对齐后的病因|<->病因类别|

# %% [markdown]
# # 构建节点和关系类型

# %% [markdown]
# 从原数据中分析可知，我们需要定义：
#
# 1. Node 节点类型：疾病 、具体的病因、病因的类别
# 2. Relationship 关系类型：疾病的致病原因、病因属于什么病因类别
#
# 即：`(疾病)-[病因]->(具体病因)` 和 `(具体病因)-[属于]->(病因类别)` 。

# %% [markdown]
# # 开始构建 疾病与病因的数据库

# %% [markdown]
# ## 读取数据，并解析出各个字段

# %%
import re

regx = re.compile('<->') # 用于切分字段

data = [] 
with open('./data/disease_cause_entity_label.txt','r',encoding='utf-8') as fi:
    for line in fi:
        result = regx.split(line.strip())
        data.append(result)

data[:5]
# Out:
# [['疾病', '病因', '具体病因', '实体对齐后的病因', '类别'],
#  ['新生儿惊厥', '病因', '围产期窒息', '围产期窒息', '既往史'],
#  ['新生儿惊厥', '病因', '产伤性颅内出血', '产伤性颅内出血', '既往史'],
#  ['新生儿惊厥', '病因', '宫内感染风疹', '宫内感染风疹', '病原体'],
#  ['新生儿惊厥', '病因', '宫内感染弓形虫', '宫内感染弓形虫', '病原体']]

# %% [markdown]
# ## 连接neo4j数据库

# %%
from py2neo import Graph

graph = Graph('http://localhost:7474',username='neo4j',password='1990121')

# %%
statement = 'match(p:疾病)-[r:病因]->(g:具体病因) where p.name="感冒" and g.name="咳嗽"  return r'
temp = graph.evaluate(statement)
print(temp)
# Out:
# None

# %% [markdown]
# ## 创建节点 和 节点之间的关系

# %%
count = 0
for line in data:
    # 过滤出 无效的数据
    if line[0] == line[3] or line[3] == line[4]:
        continue
    # 给节点 和 关系 添加唯一约束
    if count == 0:
        # 节点
        statement = 'create constraint on (p:疾病) assert p.name is unique'
        graph.evaluate(statement)
        statement = 'create constraint on (p:具体病因) assert p.name is unique'
        graph.evaluate(statement)
        statement = 'create constraint on (p:病因类别) assert p.name is unique'
        graph.evaluate(statement)
        
        # 关系
        statement = 'create constraint on (r:病因) assert r.name is unique'
        graph.evaluate(statement)
        statement = 'create constraint on (r:属于) assert r.name is unique'
        graph.evaluate(statement)
        count += 1
        continue
    
    
    # 查找节点是否存在
    statement = 'match(p:疾病) where p.name="%s" return p'%line[0] # match 后必须有return语句
    temp = graph.evaluate(statement)
    if temp == None:
        # 如果不存在该节点，则创建节点
        statement = 'create (p:疾病{name:"%s"}) return p'%(line[0])
        graph.evaluate(statement)
        
    statement = 'match(p:具体病因) where p.name="%s" return p'%line[3]
    temp = graph.evaluate(statement)
    if temp == None:
        # 如果不存在该节点，则创建节点
        statement = 'create (p:具体病因{name:"%s"}) return p'%(line[3])
        graph.evaluate(statement)
        
    statement = 'match(p:病因类别) where p.name="%s" return p'%line[4]
    temp = graph.evaluate(statement)
    if temp == None:
        # 如果不存在该节点，则创建节点
        statement = 'create (p:病因类别{name:"%s"}) return p'%(line[4])
        graph.evaluate(statement)

    # 查找关系是否存在
    statement = 'match(p:疾病)-[r:病因]->(q:具体病因) where p.name="%s" and q.name="%s" return r'%(line[0],line[3])
    temp = graph.evaluate(statement)
    print(temp,line[0],line[4])
    if temp == None:
        # 如果不存在该节点，则创建节点
        statement = 'match (p:疾病),(g:具体病因) where p.name= "%s" and g.name="%s" create (p)-[r:病因]->(g) '%(line[0],line[3])
        graph.evaluate(statement)
        
    statement = 'match(p:具体病因)-[r:属于]->(q:病因类别) where p.name="%s" and q.name="%s" return r'%(line[3],line[4])
    temp = graph.evaluate(statement)
    print(temp,line[3],line[4])
    if temp == None:
        # 如果不存在该节点，则创建节点
        statement = 'match (p:具体病因),(g:病因类别) where p.name= "%s" and g.name="%s" create (p)-[r:属于]->(g) '%(line[3],line[4])
        graph.evaluate(statement)
    
    count += 1
# Out:
# None 新生儿惊厥 既往史
# None 围产期窒息 既往史
# (新生儿惊厥)-[:病因 {}]->(产伤性颅内出血) 新生儿惊厥 既往史
# (产伤性颅内出血)-[:属于 {}]->(既往史) 产伤性颅内出血 既往史
# (新生儿惊厥)-[:病因 {}]->(宫内感染风疹) 新生儿惊厥 病原体
# (宫内感染风疹)-[:属于 {}]->(病原体) 宫内感染风疹 病原体
# (新生儿惊厥)-[:病因 {}]->(宫内感染弓形虫) 新生儿惊厥 病原体
# (宫内感染弓形虫)-[:属于 {}]->(病原体) 宫内感染弓形虫 病原体
# (新生儿惊厥)-[:病因 {}]->(宫内感染巨细胞病毒) 新生儿惊厥 病原体
# (宫内感染巨细胞病毒)-[:属于 {}]->(病原体) 宫内感染巨细胞病毒 病原体
# (新生儿惊厥)-[:病因 {}]->(代谢异常) 新生儿惊厥 身体状态
# (代谢异常)-[:属于 {}]->(身体状态) 代谢异常 身体状态
# (新生儿肺炎)-[:病因 {}]->(新生儿吸入性肺炎) 新生儿肺炎 既往史
# (新生儿吸入性肺炎)-[:属于 {}]->(既往史) 新生儿吸入性肺炎 既往史
# (新生儿肺炎)-[:病因 {}]->(新生儿感染性肺炎) 新生儿肺炎 既往史
# (新生儿感染性肺炎)-[:属于 {}]->(既往史) 新生儿感染性肺炎 既往史
# (矮小症)-[:病因 {}]->(生长激素缺乏) 矮小症 身体状态
# (生长激素缺乏)-[:属于 {}]->(身体状态) 生长激素缺乏 身体状态
# (矮小症)-[:病因 {}]->(生长激素分泌不足) 矮小症 身体状态
# (生长激素分泌不足)-[:属于 {}]->(身体状态) 生长激素分泌不足 身体状态
# (矮小症)-[:病因 {}]->(家族性矮身材) 矮小症 既往史
# (家族性矮身材)-[:属于 {}]->(既往史) 家族性矮身材 既往史
# (矮小症)-[:病因 {}]->(生长激素不敏感) 矮小症 身体状态
# (生长激素不敏感)-[:属于 {}]->(身体状态) 生长激素不敏感 身体状态
# (矮小症)-[:病因 {}]->(抵抗综合征) 矮小症 既往史
# (抵抗综合征)-[:属于 {}]->(既往史) 抵抗综合征 既往史
# (矮小症)-[:病因 {}]->(先天性卵巢发育不全) 矮小症 先天因素
# (先天性卵巢发育不全)-[:属于 {}]->(先天因素) 先天性卵巢发育不全 先天因素
# (矮小症)-[:病因 {}]->(Turner综合征) 矮小症 既往史
# (Turner综合征)-[:属于 {}]->(既往史) Turner综合征 既往史
# (矮小症)-[:病因 {}]->(宫内生长迟缓) 矮小症 身体状态
# (宫内生长迟缓)-[:属于 {}]->(身体状态) 宫内生长迟缓 身体状态
# (关节退行性病变)-[:病因 {}]->(职业因素) 关节退行性病变 职业
# (职业因素)-[:属于 {}]->(职业) 职业因素 职业
# (关节退行性病变)-[:病因 {}]->(个体体质) 关节退行性病变 体型结构
# (个体体质)-[:属于 {}]->(体型结构) 个体体质 体型结构
# (营养不良)-[:病因 {}]->(喂养不当) 营养不良 生活习惯
# (喂养不当)-[:属于 {}]->(生活习惯) 喂养不当 生活习惯
# (营养不良)-[:病因 {}]->(疾病因素) 营养不良 既往史
# (疾病因素)-[:属于 {}]->(既往史) 疾病因素 既往史
# (产后出血)-[:病因 {}]->(宫缩乏力) 产后出血 身体状态
# (宫缩乏力)-[:属于 {}]->(身体状态) 宫缩乏力 身体状态
# (产后出血)-[:病因 {}]->(胎盘) 产后出血 发育
# (胎盘)-[:属于 {}]->(发育) 胎盘 发育
# (产后出血)-[:病因 {}]->(凝血功能障碍) 产后出血 身体状态
# (凝血功能障碍)-[:属于 {}]->(身体状态) 凝血功能障碍 身体状态
# (产后出血)-[:病因 {}]->(子宫内翻) 产后出血 身体状态
# (子宫内翻)-[:属于 {}]->(身体状态) 子宫内翻 身体状态
# (前置胎盘)-[:病因 {}]->(子宫内膜受损) 前置胎盘 身体状态
# (子宫内膜受损)-[:属于 {}]->(身体状态) 子宫内膜受损 身体状态
# (前置胎盘)-[:病因 {}]->(滋养层发育迟缓) 前置胎盘 发育
# (滋养层发育迟缓)-[:属于 {}]->(发育) 滋养层发育迟缓 发育
# (前置胎盘)-[:病因 {}]->(吸烟及毒品影响子宫胎盘供血) 前置胎盘 发育
# (吸烟及毒品影响子宫胎盘供血)-[:属于 {}]->(发育) 吸烟及毒品影响子宫胎盘供血 发育
# (多胎妊娠)-[:病因 {}]->(产次因素) 多胎妊娠 既往史
# (产次因素)-[:属于 {}]->(既往史) 产次因素 既往史
# (多胎妊娠)-[:病因 {}]->(内源性促性腺激素) 多胎妊娠 身体状态
# (内源性促性腺激素)-[:属于 {}]->(身体状态) 内源性促性腺激素 身体状态
# (多胎妊娠)-[:病因 {}]->(服用促排卵药物) 多胎妊娠 化学药品
# (服用促排卵药物)-[:属于 {}]->(化学药品) 服用促排卵药物 化学药品
# (妊娠子宫破裂)-[:病因 {}]->(梗阻性难产) 妊娠子宫破裂 既往史
# (梗阻性难产)-[:属于 {}]->(既往史) 梗阻性难产 既往史
# (妊娠子宫破裂)-[:病因 {}]->(子宫瘢痕破裂) 妊娠子宫破裂 身体状态
# (子宫瘢痕破裂)-[:属于 {}]->(身体状态) 子宫瘢痕破裂 身体状态
# (妊娠子宫破裂)-[:病因 {}]->(滥用宫缩剂) 妊娠子宫破裂 化学药品
# (滥用宫缩剂)-[:属于 {}]->(化学药品) 滥用宫缩剂 化学药品
# (妊娠子宫破裂)-[:病因 {}]->(子宫发育畸形) 妊娠子宫破裂 发育
# (子宫发育畸形)-[:属于 {}]->(发育) 子宫发育畸形 发育
# (其他因素)-[:属于 {}]->(生长激素不敏感) 妊娠子宫破裂 发育
# (子宫壁发育不良)-[:属于 {}]->(发育) 子宫壁发育不良 发育
# (妊娠子宫破裂)-[:病因 {}]->(子宫病变) 妊娠子宫破裂 既往史
# (子宫病变)-[:属于 {}]->(既往史) 子宫病变 既往史
# (异位妊娠)-[:病因 {}]->(受精卵游走) 异位妊娠 身体状态
# (受精卵游走)-[:属于 {}]->(身体状态) 受精卵游走 身体状态
# (早产)-[:病因 {}]->(胎膜早破) 早产 发育
# (胎膜早破)-[:属于 {}]->(发育) 胎膜早破 发育
# (早产)-[:病因 {}]->(下生殖道感染) 早产 病原体
# (下生殖道感染)-[:属于 {}]->(病原体) 下生殖道感染 病原体
# (早产)-[:病因 {}]->(泌尿系统感染) 早产 病原体
# (泌尿系统感染)-[:属于 {}]->(病原体) 泌尿系统感染 病原体
# (早产)-[:病因 {}]->(妊娠合并症) 早产 身体状态
# (妊娠合并症)-[:属于 {}]->(身体状态) 妊娠合并症 身体状态
# (早产)-[:病因 {}]->(妊娠并发症) 早产 身体状态
# (妊娠并发症)-[:属于 {}]->(身体状态) 妊娠并发症 身体状态
# (早产)-[:病因 {}]->(子宫过大) 早产 身体状态
# (子宫过大)-[:属于 {}]->(身体状态) 子宫过大 身体状态
# (早产)-[:病因 {}]->(胎盘) 早产 发育
# (胎盘)-[:属于 {}]->(发育) 胎盘 发育
# (早产)-[:病因 {}]->(子宫发育畸形) 早产 发育
# (子宫发育畸形)-[:属于 {}]->(发育) 子宫发育畸形 发育
# (早产)-[:病因 {}]->(前置胎盘) 早产 发育
# (前置胎盘)-[:属于 {}]->(发育) 前置胎盘 发育
# (早产)-[:病因 {}]->(羊水过多) 早产 身体状态
# (羊水过多)-[:属于 {}]->(身体状态) 羊水过多 身体状态
# (早产)-[:病因 {}]->(严重的溶血病) 早产 既往史
# (严重的溶血病)-[:属于 {}]->(既往史) 严重的溶血病 既往史
# (早产)-[:病因 {}]->(子宫内膜炎) 早产 既往史
# (子宫肿瘤)-[:病因 {}]->(免疫力因素) 子宫内膜炎 既往史
# (早产)-[:病因 {}]->(子宫颈口松弛) 早产 身体状态
# (子宫颈口松弛)-[:属于 {}]->(身体状态) 子宫颈口松弛 身体状态
# (早产)-[:病因 {}]->(双胎) 早产 身体状态
# (双胎)-[:属于 {}]->(身体状态) 双胎 身体状态
# (早产)-[:病因 {}]->(胎儿畸形) 早产 发育
# (胎儿畸形)-[:属于 {}]->(发育) 胎儿畸形 发育
# (早产)-[:病因 {}]->(羊水过多) 早产 身体状态
# (羊水过多)-[:属于 {}]->(身体状态) 羊水过多 身体状态
# (早产儿)-[:病因 {}]->(妊娠期高血压) 早产儿 既往史
# (妊娠期高血压)-[:属于 {}]->(既往史) 妊娠期高血压 既往史
# (早产儿)-[:病因 {}]->(早期破水) 早产儿 身体状态
# (早期破水)-[:属于 {}]->(身体状态) 早期破水 身体状态
# (早产儿)-[:病因 {}]->(多胎妊娠) 早产儿 身体状态
# (多胎妊娠)-[:属于 {}]->(身体状态) 多胎妊娠 身体状态
# (早产儿)-[:病因 {}]->(慢性疾病) 早产儿 既往史
# (慢性疾病)-[:属于 {}]->(既往史) 慢性疾病 既往史
# (早产儿)-[:病因 {}]->(贫血) 早产儿 既往史
# (贫血)-[:属于 {}]->(既往史) 贫血 既往史
# (早产儿)-[:病因 {}]->(急性传染病伴有高热) 早产儿 既往史
# (急性传染病伴有高热)-[:属于 {}]->(既往史) 急性传染病伴有高热 既往史
# (早产儿)-[:病因 {}]->(子宫肿瘤) 早产儿 既往史
# (子宫肿瘤)-[:属于 {}]->(既往史) 子宫肿瘤 既往史
# (早产儿)-[:病因 {}]->(情绪剧烈波动) 早产儿 心理状态
# (情绪剧烈波动)-[:属于 {}]->(心理状态) 情绪剧烈波动 心理状态
# (流产)-[:病因 {}]->(环境因素) 流产 环境病因
# (环境因素)-[:属于 {}]->(环境病因) 环境因素 环境病因
# (流产)-[:病因 {}]->(全身性疾病) 流产 既往史
# (全身性疾病)-[:属于 {}]->(既往史) 全身性疾病 既往史
# (流产)-[:病因 {}]->(生殖器官疾病) 流产 既往史
# (生殖器官疾病)-[:属于 {}]->(既往史) 生殖器官疾病 既往史
# (流产)-[:病因 {}]->(内分泌失调) 流产 身体状态
# (内分泌失调)-[:属于 {}]->(身体状态) 内分泌失调 身体状态
# (流产)-[:病因 {}]->(创伤) 流产 既往史
# (创伤)-[:属于 {}]->(既往史) 创伤 既往史
# (流产)-[:病因 {}]->(免疫力因素) 流产 身体状态
# (免疫力因素)-[:属于 {}]->(身体状态) 免疫力因素 身体状态
# (羊水过多)-[:病因 {}]->(胎儿畸形) 羊水过多 发育
# (胎儿畸形)-[:属于 {}]->(发育) 胎儿畸形 发育
# (羊水过多)-[:病因 {}]->(多胎妊娠) 羊水过多 身体状态
# (多胎妊娠)-[:属于 {}]->(身体状态) 多胎妊娠 身体状态
# (羊水过多)-[:病因 {}]->(母儿血型不合) 羊水过多 身体状态
# (母儿血型不合)-[:属于 {}]->(身体状态) 母儿血型不合 身体状态
# (瘢痕癌)-[:病因 {}]->(烧伤后的不稳定瘢痕组织) 瘢痕癌 身体状态
# (烧伤后的不稳定瘢痕组织)-[:属于 {}]->(身体状态) 烧伤后的不稳定瘢痕组织 身体状态
# (瘢痕癌)-[:病因 {}]->(下肢慢性溃疡) 瘢痕癌 既往史
# (下肢慢性溃疡)-[:属于 {}]->(既往史) 下肢慢性溃疡 既往史
# (瘢痕癌)-[:病因 {}]->(慢性骨髓炎窦道的瘢痕组织) 瘢痕癌 身体状态
# (慢性骨髓炎窦道的瘢痕组织)-[:属于 {}]->(身体状态) 慢性骨髓炎窦道的瘢痕组织 身体状态
# (瘢痕癌)-[:病因 {}]->(放射性溃疡) 瘢痕癌 电离辐射
# (放射性溃疡)-[:属于 {}]->(电离辐射) 放射性溃疡 电离辐射
# (_363)-[:属于 {}]->(_364) 瘢痕癌 既往史
# (烧伤)-[:属于 {}]->(既往史) 烧伤 既往史
# (瘢痕癌)-[:病因 {}]->(下肢慢性溃疡) 瘢痕癌 既往史
# (下肢慢性溃疡)-[:属于 {}]->(既往史) 下肢慢性溃疡 既往史
# (瘢痕癌)-[:病因 {}]->(慢性骨髓炎窦道) 瘢痕癌 既往史
# (慢性骨髓炎窦道)-[:属于 {}]->(既往史) 慢性骨髓炎窦道 既往史
# (瘢痕癌)-[:病因 {}]->(放射性溃疡) 瘢痕癌 电离辐射
# (放射性溃疡)-[:属于 {}]->(电离辐射) 放射性溃疡 电离辐射
# (小儿烧伤休克)-[:病因 {}]->(热力烧伤) 小儿烧伤休克 既往史
# (热力烧伤)-[:属于 {}]->(既往史) 热力烧伤 既往史
# (小儿重度烧伤)-[:病因 {}]->(热力烧伤) 小儿重度烧伤 既往史
# (热力烧伤)-[:属于 {}]->(既往史) 热力烧伤 既往史
# (小儿重度烧伤)-[:病因 {}]->(特殊原因烧伤) 小儿重度烧伤 既往史
# (特殊原因烧伤)-[:属于 {}]->(既往史) 特殊原因烧伤 既往史
# (羊水过少)-[:病因 {}]->(胎儿畸形) 羊水过少 发育
# (胎儿畸形)-[:属于 {}]->(发育) 胎儿畸形 发育
# (羊水过少)-[:病因 {}]->(药物中毒) 羊水过少 化学药品
# (药物中毒)-[:属于 {}]->(化学药品) 药物中毒 化学药品
# (胎儿窘迫)-[:病因 {}]->(母体红细胞携氧量不足) 胎儿窘迫 身体状态
# (母体红细胞携氧量不足)-[:属于 {}]->(身体状态) 母体红细胞携氧量不足 身体状态
# (胎儿窘迫)-[:病因 {}]->(母体微小动脉供血不足) 胎儿窘迫 身体状态
# (母体微小动脉供血不足)-[:属于 {}]->(身体状态) 母体微小动脉供血不足 身体状态
# (胎儿窘迫)-[:病因 {}]->(母体红细胞携氧量不足) 胎儿窘迫 身体状态
# (母体红细胞携氧量不足)-[:属于 {}]->(身体状态) 母体红细胞携氧量不足 身体状态
# (胎儿窘迫)-[:病因 {}]->(母体急性失血) 胎儿窘迫 既往史
# (母体急性失血)-[:属于 {}]->(既往史) 母体急性失血 既往史
# (胎儿窘迫)-[:病因 {}]->(母体子宫胎盘血运受阻) 胎儿窘迫 身体状态
# (母体子宫胎盘血运受阻)-[:属于 {}]->(身体状态) 母体子宫胎盘血运受阻 身体状态
# (胎儿窘迫)-[:病因 {}]->(胎儿畸形) 胎儿窘迫 发育
# (胎儿畸形)-[:属于 {}]->(发育) 胎儿畸形 发育
# (胎盘早剥)-[:病因 {}]->(血管病变) 胎盘早剥 既往史
# (血管病变)-[:属于 {}]->(既往史) 血管病变 既往史
# (胎盘早剥)-[:病因 {}]->(子宫静脉压突然升高) 胎盘早剥 身体状态
# (_462)-[:病因 {}]->(_463) 子宫静脉压突然升高 身体状态
# (胎盘早剥)-[:病因 {}]->(吸烟) 胎盘早剥 嗜好兴趣
# (吸烟)-[:属于 {}]->(嗜好兴趣) 吸烟 嗜好兴趣
# None 胎盘早剥 发育
# (胎膜早破)-[:属于 {}]->(发育) 胎膜早破 发育
# None 胎盘早剥 化学药品
# None 滥用可卡因 化学药品
# None 胎盘早剥 年龄
# None 孕妇年龄 年龄
# None 胎盘早剥 身体状态
# None 孕妇产次 身体状态
# None 胎膜早破 病原体
# None 感染 病原体
# None 胎膜早破 身体状态
# None 子宫颈功能不全 身体状态
# None 胎膜早破 心理状态
# None 宫腔内压力异常 心理状态
# None 胎膜早破 既往史
# (创伤)-[:属于 {}]->(既往史) 创伤 既往史
# None 脐带脱垂 身体状态
# None 异常胎先露 身体状态
# None 脐带脱垂 发育
# None 早产 发育
# None 脐带脱垂 身体状态
# None 双胎妊娠 身体状态
# None 脐带脱垂 身体状态
# None 脐带过长 身体状态
# None 输卵管妊娠 身体状态
# (受精卵游走)-[:属于 {}]->(身体状态) 受精卵游走 身体状态
# None 黄体囊肿 身体状态
# None 卵泡膜黄素囊肿 身体状态
# None 肠息肉 既往史
# None 炎症 既往史
# None 肠息肉 发育
# None 胚胎异常 发育
# None 肠息肉 病原体
# None 病毒感染 病原体
# None 慢性非萎缩性胃炎 病原体
# None 幽门螺杆菌感染 病原体
# None 糜烂性胃炎 既往史
# None 严重创伤 既往史
# None 糜烂性胃炎 既往史
# None 大面积烧伤 既往史
# None 糜烂性胃炎 既往史
# None 休克 既往史
# None 糜烂性胃炎 化学药品
# None 服用抗生素 化学药品
# None 直肠炎 既往史
# None 异物损伤 既往史
# None 直肠炎 病原体
# None 中毒与感染 病原体
# None 直肠炎 既往史
# None 局部炎症 既往史
# None 直肠炎 既往史
# None 性病 既往史
# None 直肠炎 身体状态
# None 免疫功能异常 身体状态
# None 直肠炎 既往史
# None 化脓性汗腺炎长期刺激肛门皮肤累及直肠下段 既往史
# None 直肠炎 既往史
# None 毛囊炎长期刺激肛门皮肤累及直肠下段 既往史
# None 直肠炎 病原体
# None 病原体感染 病原体
# None 直肠炎 电离辐射
# None 放射性照射 电离辐射
# None 脉络丛囊肿 染色体
# None 染色体异常 染色体
# None 盆腔炎症 病原体
# None 产后感染 病原体
# None 盆腔炎症 病原体
# None 流产后感染 病原体
# None 盆腔炎症 病原体
# None 宫内病毒感染 病原体
# None 盆腔炎症 生活习惯
# None 不注意经期卫生 生活习惯
# None 月经失调 心理状态
# None 情绪异常 心理状态
# None 月经失调 气象
# None 受寒 气象
# None 月经失调 嗜好兴趣
# None 嗜烟与嗜酒 嗜好兴趣
# None 子宫粘连 既往史
# None 女性宫腔操作史 既往史
# None 子宫粘连 既往史
# None 手术炎症 既往史
# None 子宫粘连 身体状态
# None 人为破坏子宫内膜基底层 身体状态
# None 成人斯蒂尔病 既往史
# None 上呼吸道感染 既往史
# None 成人斯蒂尔病 身体状态
# (免疫功能异常)-[:属于 {}]->(身体状态) 免疫功能异常 身体状态
# None 炎性肌病及其他疾病 病原体
# (病毒感染)-[:属于 {}]->(病原体) 病毒感染 病原体
# None 痛风 身体状态
# None 嘌呤代谢酶缺陷 身体状态
# None 痛风 营养状态
# None 次黄嘌呤鸟嘌呤磷酸核糖转移酶缺乏 营养状态
# None 痛风 化学药品
# (药物中毒)-[:属于 {}]->(化学药品) 药物中毒 化学药品
# None 痛风 既往史
# None 肾脏疾病 既往史
# None 系统性硬化症 环境病因
# (环境因素)-[:属于 {}]->(环境病因) 环境因素 环境病因
# None 系统性硬化症 化学药品
# None 化学物品中毒 化学药品
# None 不孕症 既往史
# None 不孕不育 既往史
# None 外阴炎 病原体
# None 大肠杆菌感染 病原体
# None 外阴炎 病原体
# None 滴虫感染 病原体
# None 外阴炎 病原体
# None 真菌感染 病原体
# None 外阴炎 病原体
# (病毒感染)-[:属于 {}]->(病原体) 病毒感染 病原体
# None 外阴炎 既往史
# (全身性疾病)-[:属于 {}]->(既往史) 全身性疾病 既往史
# None 子宫息肉 身体状态
# (内分泌失调)-[:属于 {}]->(身体状态) 内分泌失调 身体状态
# None 子宫息肉 既往史
# None 炎症刺激 既往史
# None 呆滞 心理状态
# None 受压力或者受压迫较少 心理状态
# None 呆滞 心理状态
# None 情志、情结失调 心理状态
# None 呆滞 体型结构
# (个体体质)-[:属于 {}]->(体型结构) 个体体质 体型结构
# None 精神疾病 心理状态
# None 心理因素 心理状态
# None 健忘症 社会/人口
# None 电子产品的频繁使用 社会/人口
# None 健忘症 生活习惯
# None 日常生活习惯 生活习惯
# None 健忘症 身体状态
# None 失眠或少眠 身体状态
# None 被害妄想症 身体状态
# None 器质性病变 身体状态
# None 被害妄想症 心理状态
# (心理因素)-[:属于 {}]->(心理状态) 心理因素 心理状态
# None 臆想症 心理状态
# (心理因素)-[:属于 {}]->(心理状态) 心理因素 心理状态
# None 臆想症 身体状态
# None 器质性因素 身体状态
# None 春节综合征 生活习惯
# None 暴饮暴食 生活习惯
# None 春节综合征 行为类型
# None 敬神 行为类型
# None 春节综合征 心理状态
# None 压力和亚健康 心理状态
# None 感觉统合失调 行为类型
# None 哺育不当 行为类型
# None 感觉统合失调 教育文化
# None 教育方法不当 教育文化
# None 性变态 心理状态
# (心理因素)-[:属于 {}]->(心理状态) 心理因素 心理状态
# None 性变态 环境病因
# (环境因素)-[:属于 {}]->(环境病因) 环境因素 环境病因
# None 广场恐惧症 身体状态
# None 宿主因素 身体状态
# None 广场恐惧症 心理状态
# None 敌对心理 心理状态
# None 广场恐惧症 心理状态
# None 心理阴影 心理状态
# None 精神强迫症 心理状态
# (心理因素)-[:属于 {}]->(心理状态) 心理因素 心理状态
# None 人群恐惧症 体型结构
# (个体体质)-[:属于 {}]->(体型结构) 个体体质 体型结构
# None 人群恐惧症 体型结构
# None 生理因素 体型结构
# None 人群恐惧症 心理状态
# (心理因素)-[:属于 {}]->(心理状态) 心理因素 心理状态
# None 孕期抑郁症 身体状态
# None 体内激素水平的显著变化 身体状态
# None 孕期抑郁症 心理状态
# None 家族或个人的抑郁史 心理状态
# None 青春期综合征 身体状态
# None 心理机能失衡 身体状态
# None 弱智 身体状态
# None 产前损害 身体状态
# None 弱智 身体状态
# None 分娩时产伤窒息 身体状态
# None 弱智 身体状态
# None 颅内出血 身体状态
# None 弱智 发育
# None 早产儿 发育
# None 弱智 既往史
# None 低血糖 既往史
# None 弱智 既往史
# None 核黄疸 既往史
# None 输卵管阻塞性不孕 既往史
# (炎症)-[:属于 {}]->(既往史) 炎症 既往史
# None 呼吸衰竭 既往史
# None 呼吸道病变 既往史
# None 哮喘 病原体
# None 变应原感染 病原体
# None 哮喘 病原体
# None 反复呼吸道感染 病原体
# None 哮喘 气象
# None 气候变化 气象
# None 哮喘 嗜好兴趣
# (吸烟)-[:属于 {}]->(嗜好兴趣) 吸烟 嗜好兴趣
# None 哮喘 环境因素
# None 环境污染 环境因素
# None 哮喘 心理状态
# None 精神因素 心理状态
# None 哮喘 嗜好兴趣
# None 运动 嗜好兴趣
# None 哮喘 化学药品
# (药物中毒)-[:属于 {}]->(化学药品) 药物中毒 化学药品
# None 哮喘 身体状态
# None 月经 身体状态
# None 哮喘 身体状态
# None 妊娠 身体状态
# None 哮喘 发育
# None 围生期胎儿的环境 发育
# None 肺源性心脏病 身体状态
# None 支气管 身体状态
# None 碘致甲状
# <b>limit_output extension: Maximum message size of 10000 exceeded with 10039 characters</b>
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# C:\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# C:\Anaconda3\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# C:\Anaconda3\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# C:\Anaconda3\lib\http\client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# C:\Anaconda3\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# <ipython-input-73-2c4408e89806> in <module>()
#      36         # 如果不存在该节点，则创建节点
#      37         statement = 'create (p:具体病因{name:"%s"}) return p'%(line[3])
# ---> 38         graph.evaluate(statement)
#      39
#      40     statement = 'match(p:病因类别) where p.name="%s" return p'%line[4]
#
# C:\Anaconda3\lib\site-packages\py2neo\database.py in evaluate(self, cypher, parameters, **kwparameters)
#     386                  :py:const:`None`.
#     387         """
# --> 388         return self.begin(autocommit=True).evaluate(cypher, parameters, **kwparameters)
#     389
#     390     def exists(self, subgraph):
#
# C:\Anaconda3\lib\site-packages\py2neo\database.py in evaluate(self, cypher, parameters, **kwparameters)
#     851         :returns: single return value or :const:`None`
#     852         """
# --> 853         return self.run(cypher, parameters, **kwparameters).evaluate(0)
#     854
#     855     def create(self, subgraph):
#
# C:\Anaconda3\lib\site-packages\py2neo\database.py in run(self, cypher, parameters, **kwparameters)
#     803                                              graph=self.graph,
#     804                                              keys=[],
# --> 805                                              entities=entities))
#     806         except CypherError as error:
#     807             raise GraphError.hydrate({"code": error.code, "message": error.message})
#
# C:\Anaconda3\lib\site-packages\py2neo\internal\connectors.py in run(self, statement, parameters, tx, graph, keys, entities)
#     368     def run(self, statement, parameters=None, tx=None, graph=None, keys=None, entities=None):
#     369         hydrator = JSONHydrator(version="rest", graph=graph, keys=keys, entities=entities)
# --> 370         r = self._post("/db/data/transaction/%s" % (tx or "commit"), statement, hydrator.dehydrate(parameters))
#     371         assert r.status == 200  # TODO: other codes
#     372         try:
#
# C:\Anaconda3\lib\site-packages\py2neo\internal\connectors.py in _post(self, url, statement, parameters)
#     359                                  url=url,
#     360                                  headers=dict(self.headers, **{"Content-Type": "application/json"}),
# --> 361                                  body=json_dumps({"statements": statements}))
#     362
#     363     def _delete(self, url):
#
# C:\Anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# C:\Anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     636
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#     640
#
# C:\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     365             # Read retry?
#     366             if read is False or not self._is_method_retryable(method):
# --> 367                 raise six.reraise(type(error), error, _stacktrace)
#     368             elif read is not None:
#     369                 read -= 1
#
# C:\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     683             value = tp()
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#     687
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                     # Remove the TypeError from the exception chain in Python 3;
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     386             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# C:\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# C:\Anaconda3\lib\http\client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# C:\Anaconda3\lib\http\client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# C:\Anaconda3\lib\http\client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# C:\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))

# %% [markdown]
# ## 完整程序
